# %% [markdown]
# # Heteromyidae Species Occurrences and Diversity

# %% [markdown]
# ### Intro
#
# The family Heteromyidae, situated in the order Rodentia, is characterized by smaller rodents, such as kangaroo rats and pocket mice. They are located mainly in North America, with some species reaching down into South America. There are 21 different genera, containing a total of 100 unique species. This family has had a substantial evolutionary history, dating back to around the Oligocene epoch (Alexander & Riddle, 2005). Most of these mammals can be found in the Americas. Based on geographical studies, Martin provides evidence that suggests that smaller mammals, such as those within the Heteromyidae family, have experienced higher rates of speciation. Current data suggests that this is still the case in terms of diversification (Martin, 2016). Despite their susceptibility to higher speciation rates, the family Heteromyidae is exceptionally vulnerable to habitat loss, which could ultimately lead to an extinction of several of the species within the family (Price & Endo, 1989).
#
# Thus, when it comes to conservation efforts, this family is often overlooked. These animals mostly suffer from a change in the land use brought about by humans, habitat loss, as mentioned above, and the fact that many people are unaware of their spatial distribution (Fernandez et. al, 2014). Rodents serve as a very important part of the ecosystem in terms of prey for the carnivores. Many of their habitats have been separated due to human intervention, causing isolated groups to form (Fernandez et. al, 2014). While their habitats are shrinking and the stigma created against rodents in general remain constant, it is difficult to gain public support for conservation efforts.

# %% [markdown]
# ### Citations
#
# Alexander, L. F., & Riddle, B. R. (2005). Phylogenetics of the new world rodent family heteromyidae. Journal of Mammalogy, 86(2), 366–379.
#
# Fernández, J. A., Hafner, M. S., Hafner, D. J., & Cervantes, F. A. (2014). Conservation status of rodents of the families Geomyidae and Heteromyidae of Mexico. Revista Mexicana de Biodiversidad, 85(2), 576–588.
#
# Martin, R. A. (2017). Body size in (mostly) mammals: mass, speciation rates and the translation of gamma to alpha diversity on evolutionary timescales. Historical Biology, 29(5), 576–593.
#
# Price, M. V., & Endo, P. R. (1989). Estimating the distribution and abundance of a cryptic species, Dipodomys stephensi (Rodentia: Heteromyidae), and implications for management. Conservation Biology, 3(3), 293–301.

# %% [markdown]
# ## Aren't they cute?!?!?!

# %%
# kangaroo rat
from IPython.display import Image
Image(filename = "kangaroo_rat.png")

# %%
# spiny pocket mouse
Image(filename = "spiny_pocket_mouse.png")

# %% [markdown]
# ### Shell Commands
#
# In order to get the data to work with, I downloaded it directly from the paleo database website and saved it to my downloads. To get it into the desired folder, I did the following:
#
# ```
# cp ~/Downloads/pbdb_data\(38\).csv ~/Desktop/eeb-177/eeb-177-final-project
# ```
# In order to rename it for easier coding:
#
# ```
# mv pbdb_data\(38\).csv rat_data.csv
# ```
#
# From there I checked to make sure the amount of species was over the limit:
#
# ```
# tail -n +19 rat_data.csv | cut -d "," -f 6 | sort |uniq | wc -l
# ```
# In order to make a cleaned version of the file:
#
# ```
# tail -n +18 rat_data.csv > cleaned-rat.csv
# ```
# For my diversity data, I followed the same steps and used the same code as the first two coding lines above.

# %% [markdown]
# ### Diversity Data
#
# This is my functions and grpahs for the Heteromyide diversity data.

# %%
#creating a dictionary for diversity of species in each time period
def DiversityDictionary(filename):
    diversity_dict = {} #creating an empty dictionary for the it
    diversity_data = open(filename, "r", encoding = "ISO-8859-15") 
    diversity_records = diversity_data.readlines()[21:]
    for line in diversity_records:
        line = line.replace('\"', '') 
        diversity_elements = line.split(",")
        epoch = diversity_elements[1] #setting the different epochs as the strings in column 2
        no_occurances = int(diversity_elements[8]) #setting the number of species in each epoch to the integers in column 9
        diversity_dict[epoch] = no_occurances #populating dictionary with epochs as keys and number of species as values
    return diversity_dict

# %%
div_dict = DiversityDictionary("rat_diversity.csv")
div_dict
# Out:
# {'Aquitanian': 14,
#  'Burdigalian': 22,
#  'Calabrian': 13,
#  'Chattian': 6,
#  'Gelasian': 0,
#  'Holocene': 7,
#  'Langhian': 40,
#  'Late Pleistocene': 15,
#  'Messinian': 0,
#  'Middle Pleistocene': 2,
#  'Piacenzian': 1,
#  'Rupelian': 6,
#  'Serravallian': 18,
#  'Tortonian': 19,
#  'Zanclean': 0}

# %%
# making the graph for the diversity data
import matplotlib.pyplot as plt
plt.figure(figsize=(21,8))
plt.bar(range(len(div_dict)), div_dict.values(), align='center')
plt.xticks(range(len(div_dict)), list(div_dict.keys()))
plt.title('Number of Species in Each Epoch', fontsize = 30)
plt.xlabel('Epoch', fontsize = 25)
plt.ylabel('Number of Species', fontsize = 25)

plt.show()

# %% [markdown]
# ### Duration/ Species Ranges
#
# These are all of the functions that are associated with my species range portion.

# %%
# if i wanted to calculate duration:
def calc_duration(filename):
    rat_age = [] #creates an empty dictionary where the keys and values will go into
    species = open(filename, "r", encoding = "ISO-8859-15") #will open the file with our data
    records = species.readlines()[19:] 
    for line in records:
        line = line.replace('\"', '') #removes the extra quotes
        record_elements = line.split(",") #denotes that each record element is separated by a file
        max_age = record_elements[14] #assigning max age to column 15
        min_age = record_elements[15] #assigning min age to column 16
        age = float(max_age) - float(min_age)
        rat_age.append(age)
    return rat_age

# %%
calc_duration("rat_data.csv")
# Out:
# [4.5,
#  10.370000000000001,
#  1.5,
#  1.5,
#  10.370000000000001,
#  4.5,
#  4.5,
#  4.5,
#  1.5,
#  4.5,
#  10.370000000000001,
#  4.5,
#  4.5,
#  4.5,
#  4.5,
#  4.5,
#  4.5,
#  4.5,
#  4.5,
#  10.370000000000001,
#  10.370000000000001,
#  6.0,
#  6.0,
#  4.370000000000001,
#  4.370000000000001,
#  4.370000000000001,
#  4.370000000000001,
#  4.370000000000001,
#  4.370000000000001,
#  4.370000000000001,
#  4.370000000000001,
#  4.370000000000001,
#  4.370000000000001,
#  4.370000000000001,
#  4.370000000000001,
#  10.370000000000001,
#  10.370000000000001,
#  10.370000000000001,
#  4.459999999999999,
#  4.459999999999999,
#  4.459999999999999,
#  4.459999999999999,
#  4.459999999999999,
#  4.459999999999999,
#  4.459999999999999,
#  4.459999999999999,
#  4.459999999999999,
#  4.459999999999999,
#  4.459999999999999,
#  4.459999999999999,
#  4.459999999999999,
#  4.459999999999999,
#  4.459999999999999,
#  4.459999999999999,
#  4.459999999999999,
#  4.459999999999999,
#  4.459999999999999,
#  4.459999999999999,
#  4.459999999999999,
#  4.459999999999999,
#  4.459999999999999,
#  4.459999999999999,
#  2.370000000000001,
#  2.370000000000001,
#  2.370000000000001,
#  2.370000000000001,
#  2.370000000000001,
#  2.370000000000001,
#  2.370000000000001,
#  2.370000000000001,
#  3.299999999999999,
#  3.299999999999999,
#  3.299999999999999,
#  5.4,
#  3.299999999999999,
#  2.370000000000001,
#  3.299999999999999,
#  2.370000000000001,
#  2.370000000000001,
#  5.4,
#  5.4,
#  2.370000000000001,
#  2.370000000000001,
#  2.370000000000001,
#  3.299999999999999,
#  2.370000000000001,
#  2.370000000000001,
#  2.370000000000001,
#  2.370000000000001,
#  2.370000000000001,
#  2.370000000000001,
#  2.370000000000001,
#  2.370000000000001,
#  2.370000000000001,
#  2.370000000000001,
#  2.370000000000001,
#  2.370000000000001,
#  2.370000000000001,
#  2.370000000000001,
#  2.370000000000001,
#  2.370000000000001,
#  2.370000000000001,
#  17.697000000000003,
#  2.370000000000001,
#  2.370000000000001,
#  3.299999999999999,
#  2.370000000000001,
#  2.370000000000001,
#  2.370000000000001,
#  2.370000000000001,
#  2.370000000000001,
#  2.370000000000001,
#  2.370000000000001,
#  2.370000000000001,
#  17.697000000000003,
#  3.299999999999999,
#  3.299999999999999,
#  3.299999999999999,
#  2.370000000000001,
#  3.299999999999999,
#  17.697000000000003,
#  2.370000000000001,
#  2.370000000000001,
#  2.370000000000001,
#  2.370000000000001,
#  2.370000000000001,
#  2.370000000000001,
#  3.299999999999999,
#  2.370000000000001,
#  2.370000000000001,
#  2.370000000000001,
#  2.370000000000001,
#  3.299999999999999,
#  2.370000000000001,
#  2.370000000000001,
#  2.370000000000001,
#  5.4,
#  4.459999999999999,
#  2.370000000000001,
#  2.370000000000001,
#  4.459999999999999,
#  4.459999999999999,
#  4.459999999999999,
#  4.459999999999999,
#  4.459999999999999,
#  4.459999999999999,
#  2.59,
#  2.59,
#  5.4,
#  2.370000000000001,
#  2.370000000000001,
#  2.370000000000001,
#  2.370000000000001,
#  2.370000000000001,
#  2.370000000000001,
#  2.370000000000001,
#  2.370000000000001,
#  2.370000000000001,
#  2.370000000000001,
#  2.370000000000001,
#  2.370000000000001,
#  2.370000000000001,
#  5.4,
#  5.4,
#  3.299999999999999,
#  3.299999999999999,
#  3.299999999999999,
#  2.370000000000001,
#  2.370000000000001,
#  2.370000000000001,
#  3.299999999999999,
#  3.299999999999999,
#  3.299999999999999,
#  5.4,
#  5.4,
#  5.4,
#  5.4,
#  5.4,
#  5.4,
#  5.4,
#  5.4,
#  2.370000000000001,
#  2.370000000000001,
#  2.370000000000001,
#  2.370000000000001,
#  2.370000000000001,
#  2.370000000000001,
#  4.459999999999999,
#  4.459999999999999,
#  4.459999999999999,
#  4.459999999999999,
#  4.459999999999999,
#  4.459999999999999,
#  4.459999999999999,
#  4.459999999999999,
#  4.459999999999999,
#  4.459999999999999,
#  5.4,
#  5.4,
#  5.4,
#  5.4,
#  5.4,
#  2.370000000000001,
#  2.370000000000001,
#  2.370000000000001,
#  2.370000000000001,
#  2.370000000000001,
#  2.370000000000001,
#  2.370000000000001,
#  2.370000000000001,
#  2.370000000000001,
#  2.370000000000001,
#  3.299999999999999,
#  3.299999999999999,
#  2.370000000000001,
#  2.370000000000001,
#  2.370000000000001,
#  2.370000000000001,
#  2.370000000000001,
#  2.370000000000001,
#  3.299999999999999,
#  3.299999999999999,
#  2.370000000000001,
#  2.370000000000001,
#  2.370000000000001,
#  2.370000000000001,
#  2.370000000000001,
#  2.370000000000001,
#  4.459999999999999,
#  4.459999999999999,
#  2.370000000000001,
#  2.370000000000001,
#  2.370000000000001,
#  2.370000000000001,
#  2.370000000000001,
#  2.370000000000001,
#  2.370000000000001,
#  2.370000000000001,
#  2.370000000000001,
#  2.370000000000001,
#  2.370000000000001,
#  2.370000000000001,
#  2.370000000000001,
#  2.370000000000001,
#  2.370000000000001,
#  2.370000000000001,
#  2.370000000000001,
#  2.370000000000001,
#  2.370000000000001,
#  2.370000000000001,
#  2.370000000000001,
#  2.370000000000001,
#  17.697000000000003,
#  17.697000000000003,
#  2.370000000000001,
#  2.370000000000001,
#  2.370000000000001,
#  2.370000000000001,
#  2.370000000000001,
#  2.370000000000001,
#  3.299999999999999,
#  3.299999999999999,
#  3.299999999999999,
#  2.370000000000001,
#  2.370000000000001,
#  2.370000000000001,
#  2.370000000000001,
#  3.299999999999999,
#  2.370000000000001,
#  2.370000000000001,
#  2.370000000000001,
#  2.370000000000001,
#  3.299999999999999,
#  3.299999999999999,
#  3.299999999999999,
#  3.299999999999999,
#  3.299999999999999,
#  2.370000000000001,
#  2.370000000000001,
#  2.370000000000001,
#  2.370000000000001,
#  2.370000000000001,
#  2.370000000000001,
#  2.370000000000001,
#  2.370000000000001,
#  2.370000000000001,
#  2.370000000000001,
#  2.370000000000001,
#  2.370000000000001,
#  5.4,
#  5.4,
#  5.4,
#  3.299999999999999,
#  3.299999999999999,
#  3.299999999999999,
#  2.370000000000001,
#  2.370000000000001,
#  2.370000000000001,
#  2.370000000000001,
#  2.370000000000001,
#  2.370000000000001,
#  2.370000000000001,
#  2.370000000000001,
#  2.370000000000001,
#  2.370000000000001,
#  2.370000000000001,
#  17.697000000000003,
#  3.299999999999999,
#  2.370000000000001,
#  2.370000000000001,
#  2.370000000000001,
#  2.370000000000001,
#  2.370000000000001,
#  2.370000000000001,
#  2.370000000000001,
#  2.370000000000001,
#  2.370000000000001,
#  2.370000000000001,
#  2.370000000000001,
#  2.370000000000001,
#  2.370000000000001,
#  2.370000000000001,
#  2.370000000000001,
#  17.697000000000003,
#  17.697000000000003,
#  17.697000000000003,
#  17.697000000000003,
#  17.697000000000003,
#  17.697000000000003,
#  2.370000000000001,
#  2.370000000000001,
#  2.370000000000001,
#  17.697000000000003,
#  4.459999999999999,
#  4.459999999999999,
#  2.370000000000001,
#  5.4,
#  3.1000000000000005,
#  3.1000000000000005,
#  3.1000000000000005,
#  3.1000000000000005,
#  3.1000000000000005,
#  3.1000000000000005,
#  3.1000000000000005,
#  3.1000000000000005,
#  3.1000000000000005,
#  3.1000000000000005,
#  3.1000000000000005,
#  3.1000000000000005,
#  4.6000000000000005,
#  3.1000000000000005,
#  3.1000000000000005,
#  3.1000000000000005,
#  3.1000000000000005,
#  3.1000000000000005,
#  3.1000000000000005,
#  3.1000000000000005,
#  3.1000000000000005,
#  3.1000000000000005,
#  3.1000000000000005,
#  3.1000000000000005,
#  3.1000000000000005,
#  3.1000000000000005,
#  3.1000000000000005,
#  3.1000000000000005,
#  3.1000000000000005,
#  3.1000000000000005,
#  3.1000000000000005,
#  3.1000000000000005,
#  3.1000000000000005,
#  3.1000000000000005,
#  3.1000000000000005,
#  3.1000000000000005,
#  3.1000000000000005,
#  3.1000000000000005,
#  3.1000000000000005,
#  3.1000000000000005,
#  3.1000000000000005,
#  3.1000000000000005,
#  3.1000000000000005,
#  3.1000000000000005,
#  3.1000000000000005,
#  3.1000000000000005,
#  3.1000000000000005,
#  3.1000000000000005,
#  3.1000000000000005,
#  3.1000000000000005,
#  3.1000000000000005,
#  3.1000000000000005,
#  3.1000000000000005,
#  3.1000000000000005,
#  3.1000000000000005,
#  3.1000000000000005,
#  3.1000000000000005,
#  3.1000000000000005,
#  3.1000000000000005,
#  3.1000000000000005,
#  3.1000000000000005,
#  3.1000000000000005,
#  3.1000000000000005,
#  3.1000000000000005,
#  3.1000000000000005,
#  3.1000000000000005,
#  3.1000000000000005,
#  3.1000000000000005,
#  3.1000000000000005,
#  3.1000000000000005,
#  3.1000000000000005,
#  3.1000000000000005,
#  3.1000000000000005,
#  3.1000000000000005,
#  3.1000000000000005,
#  3.1000000000000005,
#  3.1000000000000005,
#  3.1000000000000005,
#  3.1000000000000005,
#  3.1000000000000005,
#  3.1000000000000005,
#  3.1000000000000005,
#  1.5,
#  1.5,
#  1.5,
#  1.5,
#  1.788,
#  1.5,
#  1.5,
#  1.5,
#  1.5,
#  1.5,
#  1.5,
#  1.5,
#  1.5,
#  1.5,
#  1.5,
#  1.5,
#  1.5,
#  0.655,
#  1.5,
#  1.5,
#  1.5,
#  1.5,
#  1.5,
#  1.5,
#  1.5,
#  1.5,
#  1.5,
#  1.5,
#  1.5,
#  0.1143,
#  0.1143,
#  0.1143,
#  0.1143,
#  0.1143,
#  4.459999999999999,
#  2.370000000000001,
#  0.0117,
#  0.0117,
#  4.5,
#  4.5,
#  4.5,
#  1.5,
#  4.370000000000001,
#  4.370000000000001,
#  4.459999999999999,
#  4.459999999999999,
#  4.459999999999999,
#  4.459999999999999,
#  4.459999999999999,
#  4.459999999999999,
#  4.459999999999999,
#  4.459999999999999,
#  4.459999999999999,
#  4.459999999999999,
#  0.1143,
#  0.1143,
#  0.1143,
#  0.1143,
#  0.1143,
#  0.1143,
#  0.1143,
#  0.1143,
#  0.1143,
#  0.1143,
#  0.0117,
#  0.0117,
#  0.0117,
#  0.0117,
#  0.0117,
#  0.1143,
#  0.1143,
#  0.1143,
#  0.1143,
#  0.1143,
#  0.1143,
#  0.1143,
#  0.1143,
#  2.588,
#  0.1143,
#  0.126,
#  0.126,
#  0.126,
#  5.4,
#  5.4,
#  5.4,
#  2.370000000000001,
#  4.459999999999999,
#  4.459999999999999,
#  4.459999999999999,
#  2.4999999999999964,
#  10.370000000000001,
#  2.370000000000001,
#  17.697000000000003]

# %%
#making a dictionary for species and ages, meaning duration of their existence
def GetDuration(filename):
    rat_dict = {} #creates an empty dictionary where the keys and values will go into
    rspecies = open(filename, "r", encoding = "ISO-8859-15") #will open the file with our data
    rat_records = rspecies.readlines()[19:] #this will read the file after line 19 which cuts out the heading
    for line in rat_records:
        line = line.replace('\"', '') #removes the extra quotes
        record_elements = line.split(",") #denotes that each record element is separated by a file
        species = record_elements[5] #making species be the keys and taking the names from column 6
        max_age = record_elements[14] #assigning max age to column 15
        min_age = record_elements[15] #assigning min age to column 16
        age = float(max_age) - float(min_age) #calculating the age of the fossil
        rat_dict[species] = age #assigning the age as the values in the dictionary
    return rat_dict

# %%
mydict = GetDuration("rat_data.csv") #running the function on my specific data file
mydict
# Out:
# {'Balantiomys borealis': 2.370000000000001,
#  'Balantiomys cf. oregonensis': 2.370000000000001,
#  'Balantiomys oregonensis': 2.370000000000001,
#  'Chaetodipus cf. formosus': 0.1143,
#  'Chaetodipus cf. hispidus': 1.5,
#  'Chaetodipus hispidus': 0.1143,
#  'Cupidinimus avawatzensis': 3.299999999999999,
#  'Cupidinimus bidahochiensis': 5.4,
#  'Cupidinimus boronensis': 2.370000000000001,
#  'Cupidinimus cf. bidahochiensis': 3.1000000000000005,
#  'Cupidinimus cf. eurekensis': 2.370000000000001,
#  'Cupidinimus cf. halli': 17.697000000000003,
#  'Cupidinimus cf. kleinfelderi': 2.370000000000001,
#  'Cupidinimus cf. lindsayi': 4.459999999999999,
#  'Cupidinimus cf. tertius': 3.299999999999999,
#  'Cupidinimus cuyamensis': 3.299999999999999,
#  'Cupidinimus eurekensis': 2.370000000000001,
#  'Cupidinimus halli': 2.370000000000001,
#  'Cupidinimus kleinfelderi': 2.370000000000001,
#  'Cupidinimus lindsayi': 2.370000000000001,
#  'Cupidinimus madisonensis': 2.370000000000001,
#  'Cupidinimus n. sp. boronensis': 4.459999999999999,
#  'Cupidinimus n. sp. lindsayi': 2.370000000000001,
#  'Cupidinimus n. sp. prattensis': 3.299999999999999,
#  'Cupidinimus n. sp. smaragdinus': 2.370000000000001,
#  'Cupidinimus nebraskensis': 2.370000000000001,
#  'Cupidinimus prattensis': 3.299999999999999,
#  'Cupidinimus quartus': 3.299999999999999,
#  'Cupidinimus saskatchewanensis': 2.370000000000001,
#  'Cupidinimus tertius': 3.299999999999999,
#  'Cupidinimus whitlocki': 2.370000000000001,
#  'Dikkomys matthewi': 4.459999999999999,
#  'Dikkomys n. sp. matthewi': 4.370000000000001,
#  'Dipodomys cf. agilis': 0.1143,
#  'Dipodomys cf. deserti': 1.5,
#  'Dipodomys cf. merriami': 0.0117,
#  'Dipodomys cf. ordii': 0.1143,
#  'Dipodomys cf. spectabilis': 0.1143,
#  'Dipodomys compactus': 1.5,
#  'Dipodomys hibbardi': 3.1000000000000005,
#  'Dipodomys merriami': 0.1143,
#  'Dipodomys microps': 0.126,
#  'Dipodomys n. sp. hibbardi': 3.1000000000000005,
#  'Dipodomys n. sp. pattersoni': 1.5,
#  'Dipodomys ordii': 0.1143,
#  'Dipodomys spectabilis': 0.126,
#  'Diprionomys cf. minimus': 5.4,
#  'Diprionomys cf. parvus': 2.370000000000001,
#  'Diprionomys n. sp. minimus': 5.4,
#  'Diprionomys n. sp. parvus': 5.4,
#  'Diprionomys parvus': 5.4,
#  'Harrymys cf. magnus': 4.459999999999999,
#  'Harrymys irvini': 4.459999999999999,
#  'Harrymys magnus': 4.459999999999999,
#  'Harrymys n. sp. canadensis': 2.370000000000001,
#  'Harrymys woodi': 4.459999999999999,
#  'Heliscomys subtilis': 2.370000000000001,
#  'Kirkomys schlaikjeri': 4.5,
#  'Lignimus cf. montis': 2.370000000000001,
#  'Lignimus montis': 2.370000000000001,
#  'Lignimus n. sp. austridakotensis': 2.370000000000001,
#  'Liomys irroratus': 0.1143,
#  'Mioheteromys agrarius': 2.370000000000001,
#  'Mioheteromys amplissimus': 2.370000000000001,
#  'Mioheteromys arcarius': 2.370000000000001,
#  'Mioheteromys cf. agrarius': 3.299999999999999,
#  'Mioheteromys cf. amplissimus': 3.299999999999999,
#  'Mioheteromys n. sp. agrarius': 3.299999999999999,
#  'Mioheteromys n. sp. amplissimus': 2.370000000000001,
#  'Mioheteromys n. sp. subterior': 2.370000000000001,
#  'Mookomys altifluminis': 2.370000000000001,
#  'Mookomys n. sp. thrinax': 2.370000000000001,
#  'Oregonomys cf. pebblespringsensis': 5.4,
#  'Oregonomys cf. sargenti': 3.1000000000000005,
#  'Oregonomys magnus': 3.1000000000000005,
#  'Oregonomys n. sp. pebblespringsensis': 5.4,
#  'Oregonomys pebblespringsensis': 5.4,
#  'Oregonomys sargenti': 5.4,
#  'Peridiomys n. sp. halis': 2.370000000000001,
#  'Peridiomys n. sp. rusticus': 4.459999999999999,
#  'Peridiomys rusticus': 4.459999999999999,
#  'Perodipus montanus': 0.1143,
#  'Perognathoides n. sp. madisonensis': 2.370000000000001,
#  'Perognathus brevidens': 2.370000000000001,
#  'Perognathus cf. brevidens': 2.370000000000001,
#  'Perognathus cf. flavus': 0.1143,
#  'Perognathus cf. formosus': 0.126,
#  'Perognathus cf. furlongi': 2.370000000000001,
#  'Perognathus cf. gidleyi': 1.5,
#  'Perognathus cf. mclaughlini': 5.4,
#  'Perognathus cf. minutus': 17.697000000000003,
#  'Perognathus cf. pearlettensis': 1.5,
#  'Perognathus cf. rexroadensis': 3.1000000000000005,
#  'Perognathus cf. trojectioansrum': 3.299999999999999,
#  'Perognathus flavus': 0.1143,
#  'Perognathus furlongi': 17.697000000000003,
#  'Perognathus gidleyi': 3.1000000000000005,
#  'Perognathus henryredfieldi': 5.4,
#  'Perognathus hispidus': 0.1143,
#  'Perognathus huastecensis': 0.1143,
#  'Perognathus intermedius': 2.588,
#  'Perognathus maldei': 3.1000000000000005,
#  'Perognathus mclaughlini': 5.4,
#  'Perognathus minutus': 2.370000000000001,
#  'Perognathus n. sp. ancenensis': 2.370000000000001,
#  'Perognathus n. sp. carpenteri': 3.1000000000000005,
#  'Perognathus n. sp. dunklei': 5.4,
#  'Perognathus n. sp. maldei': 3.1000000000000005,
#  'Perognathus n. sp. mclaughlini': 3.1000000000000005,
#  'Perognathus n. sp. pearlettensis': 3.1000000000000005,
#  'Perognathus n. sp. rexroadensis': 3.1000000000000005,
#  'Perognathus n. sp. stevei': 5.4,
#  'Perognathus n. sp. strigipredus': 3.1000000000000005,
#  'Perognathus pearlettensis': 1.5,
#  'Perognathus stevei': 5.4,
#  'Perognathus trojectioansrum': 2.370000000000001,
#  'Pliosaccomys cf. magnus': 5.4,
#  'Pliosaccomys magnus': 5.4,
#  'Prodipodomys ? minor': 3.1000000000000005,
#  'Prodipodomys centralis': 3.1000000000000005,
#  'Prodipodomys cf. coquorum': 3.1000000000000005,
#  'Prodipodomys cf. idahoensis': 1.5,
#  'Prodipodomys coquorum': 5.4,
#  'Prodipodomys gidleyi': 1.5,
#  'Prodipodomys griggsorum': 3.1000000000000005,
#  'Prodipodomys idahoensis': 1.5,
#  'Prodipodomys kansensis': 5.4,
#  'Prodipodomys minor': 3.1000000000000005,
#  'Prodipodomys n. sp. idahoensis': 3.1000000000000005,
#  'Prodipodomys n. sp. riversidensis': 3.1000000000000005,
#  'Prodipodomys n. sp. timoteoensis': 3.1000000000000005,
#  'Prodipodomys riversidensis': 3.1000000000000005,
#  'Prodipodomys tiheni': 3.1000000000000005,
#  'Prodipodomys timoteoensis': 3.1000000000000005,
#  'Proharrymys n. sp. wahlerti': 4.5,
#  'Proharrymys wahlerti': 2.4999999999999964,
#  'Proheteromys aff. floridanus': 4.370000000000001,
#  'Proheteromys cf. floridanus': 10.370000000000001,
#  'Proheteromys cf. formicarum': 2.370000000000001,
#  'Proheteromys fedti': 4.5,
#  'Proheteromys floridanus': 4.459999999999999,
#  'Proheteromys formicarum': 2.370000000000001,
#  'Proheteromys gremmelsi': 4.5,
#  'Proheteromys ironcloudi': 4.5,
#  'Proheteromys maximus': 17.697000000000003,
#  'Proheteromys n. sp. cejanus': 4.370000000000001,
#  'Proheteromys n. sp. fedti': 4.5,
#  'Proheteromys n. sp. floridanus': 4.459999999999999,
#  'Proheteromys n. sp. gremmelsi': 4.5,
#  'Proheteromys n. sp. ironcloudi': 1.5,
#  'Proheteromys n. sp. matthewi': 4.370000000000001,
#  'Proheteromys n. sp. sabinensis': 2.59,
#  'Proheteromys n. sp. toledoensis': 2.59,
#  'Proheteromys sulculus': 17.697000000000003,
#  'Schizodontomys amnicolus': 4.459999999999999,
#  'Schizodontomys cf. harkseni': 4.370000000000001,
#  'Schizodontomys greeni': 10.370000000000001,
#  'Schizodontomys harkseni': 4.459999999999999,
#  'Schizodontomys n. sp. amnicolus': 4.459999999999999,
#  'Schizodontomys sulcidens': 4.370000000000001,
#  'Stratimus n. sp. strobeli': 4.459999999999999,
#  'Stratimus strobeli': 4.459999999999999,
#  'Trogomys cf. rupinimenthae': 4.459999999999999,
#  'Trogomys n. sp. rupinimenthae': 10.370000000000001,
#  'cf. Cupidinimus nebraskensis': 17.697000000000003,
#  'cf. Lignimus montis': 2.370000000000001,
#  'n. gen. Metaliomys n. sp. sevierensis': 5.4}

# %%
#making a dictionary for the species and first occurance 
def FirstOccurance(filename):
    firstocc_dict = {} #creating an empty dictionary 
    species_data = open(filename, "r", encoding = "ISO-8859-15") #will open file
    firstocc_records = species_data.readlines()[19:] #reads the file
    for line in firstocc_records:
        line = line.replace('\"', '') 
        firstocc_elements = line.split(",")
        species = firstocc_elements[5] #populating the species with the data in column 6
        start_year = float(firstocc_elements[14]) #populating the start year with data from column 15 while also converting to float
        firstocc_dict[species] = start_year #assigning species as keys and start year as values
    return firstocc_dict

# %%
fo_dict = FirstOccurance("rat_data.csv") #performing the above function on my specific file
fo_dict
# Out:
# {'Balantiomys borealis': 15.97,
#  'Balantiomys cf. oregonensis': 15.97,
#  'Balantiomys oregonensis': 15.97,
#  'Chaetodipus cf. formosus': 0.126,
#  'Chaetodipus cf. hispidus': 1.8,
#  'Chaetodipus hispidus': 0.126,
#  'Cupidinimus avawatzensis': 13.6,
#  'Cupidinimus bidahochiensis': 10.3,
#  'Cupidinimus boronensis': 15.97,
#  'Cupidinimus cf. bidahochiensis': 4.9,
#  'Cupidinimus cf. eurekensis': 15.97,
#  'Cupidinimus cf. halli': 23.03,
#  'Cupidinimus cf. kleinfelderi': 15.97,
#  'Cupidinimus cf. lindsayi': 20.43,
#  'Cupidinimus cf. tertius': 13.6,
#  'Cupidinimus cuyamensis': 13.6,
#  'Cupidinimus eurekensis': 15.97,
#  'Cupidinimus halli': 15.97,
#  'Cupidinimus kleinfelderi': 15.97,
#  'Cupidinimus lindsayi': 15.97,
#  'Cupidinimus madisonensis': 15.97,
#  'Cupidinimus n. sp. boronensis': 20.43,
#  'Cupidinimus n. sp. lindsayi': 15.97,
#  'Cupidinimus n. sp. prattensis': 13.6,
#  'Cupidinimus n. sp. smaragdinus': 15.97,
#  'Cupidinimus nebraskensis': 15.97,
#  'Cupidinimus prattensis': 13.6,
#  'Cupidinimus quartus': 13.6,
#  'Cupidinimus saskatchewanensis': 15.97,
#  'Cupidinimus tertius': 13.6,
#  'Cupidinimus whitlocki': 15.97,
#  'Dikkomys matthewi': 20.43,
#  'Dikkomys n. sp. matthewi': 24.8,
#  'Dipodomys cf. agilis': 0.126,
#  'Dipodomys cf. deserti': 1.8,
#  'Dipodomys cf. merriami': 0.0117,
#  'Dipodomys cf. ordii': 0.126,
#  'Dipodomys cf. spectabilis': 0.126,
#  'Dipodomys compactus': 1.8,
#  'Dipodomys hibbardi': 4.9,
#  'Dipodomys merriami': 0.126,
#  'Dipodomys microps': 0.126,
#  'Dipodomys n. sp. hibbardi': 4.9,
#  'Dipodomys n. sp. pattersoni': 1.8,
#  'Dipodomys ordii': 0.126,
#  'Dipodomys spectabilis': 0.126,
#  'Diprionomys cf. minimus': 10.3,
#  'Diprionomys cf. parvus': 15.97,
#  'Diprionomys n. sp. minimus': 10.3,
#  'Diprionomys n. sp. parvus': 10.3,
#  'Diprionomys parvus': 10.3,
#  'Harrymys cf. magnus': 20.43,
#  'Harrymys irvini': 20.43,
#  'Harrymys magnus': 20.43,
#  'Harrymys n. sp. canadensis': 15.97,
#  'Harrymys woodi': 20.43,
#  'Heliscomys subtilis': 15.97,
#  'Kirkomys schlaikjeri': 30.8,
#  'Lignimus cf. montis': 15.97,
#  'Lignimus montis': 15.97,
#  'Lignimus n. sp. austridakotensis': 15.97,
#  'Liomys irroratus': 0.126,
#  'Mioheteromys agrarius': 15.97,
#  'Mioheteromys amplissimus': 15.97,
#  'Mioheteromys arcarius': 15.97,
#  'Mioheteromys cf. agrarius': 13.6,
#  'Mioheteromys cf. amplissimus': 13.6,
#  'Mioheteromys n. sp. agrarius': 13.6,
#  'Mioheteromys n. sp. amplissimus': 15.97,
#  'Mioheteromys n. sp. subterior': 15.97,
#  'Mookomys altifluminis': 15.97,
#  'Mookomys n. sp. thrinax': 15.97,
#  'Oregonomys cf. pebblespringsensis': 10.3,
#  'Oregonomys cf. sargenti': 4.9,
#  'Oregonomys magnus': 4.9,
#  'Oregonomys n. sp. pebblespringsensis': 10.3,
#  'Oregonomys pebblespringsensis': 10.3,
#  'Oregonomys sargenti': 10.3,
#  'Peridiomys n. sp. halis': 15.97,
#  'Peridiomys n. sp. rusticus': 20.43,
#  'Peridiomys rusticus': 20.43,
#  'Perodipus montanus': 0.126,
#  'Perognathoides n. sp. madisonensis': 15.97,
#  'Perognathus brevidens': 15.97,
#  'Perognathus cf. brevidens': 15.97,
#  'Perognathus cf. flavus': 0.126,
#  'Perognathus cf. formosus': 0.126,
#  'Perognathus cf. furlongi': 15.97,
#  'Perognathus cf. gidleyi': 1.8,
#  'Perognathus cf. mclaughlini': 10.3,
#  'Perognathus cf. minutus': 23.03,
#  'Perognathus cf. pearlettensis': 1.8,
#  'Perognathus cf. rexroadensis': 4.9,
#  'Perognathus cf. trojectioansrum': 13.6,
#  'Perognathus flavus': 0.126,
#  'Perognathus furlongi': 23.03,
#  'Perognathus gidleyi': 4.9,
#  'Perognathus henryredfieldi': 10.3,
#  'Perognathus hispidus': 0.126,
#  'Perognathus huastecensis': 0.126,
#  'Perognathus intermedius': 2.588,
#  'Perognathus maldei': 4.9,
#  'Perognathus mclaughlini': 10.3,
#  'Perognathus minutus': 15.97,
#  'Perognathus n. sp. ancenensis': 15.97,
#  'Perognathus n. sp. carpenteri': 4.9,
#  'Perognathus n. sp. dunklei': 10.3,
#  'Perognathus n. sp. maldei': 4.9,
#  'Perognathus n. sp. mclaughlini': 4.9,
#  'Perognathus n. sp. pearlettensis': 4.9,
#  'Perognathus n. sp. rexroadensis': 4.9,
#  'Perognathus n. sp. stevei': 10.3,
#  'Perognathus n. sp. strigipredus': 4.9,
#  'Perognathus pearlettensis': 1.8,
#  'Perognathus stevei': 10.3,
#  'Perognathus trojectioansrum': 15.97,
#  'Pliosaccomys cf. magnus': 10.3,
#  'Pliosaccomys magnus': 10.3,
#  'Prodipodomys ? minor': 4.9,
#  'Prodipodomys centralis': 4.9,
#  'Prodipodomys cf. coquorum': 4.9,
#  'Prodipodomys cf. idahoensis': 1.8,
#  'Prodipodomys coquorum': 10.3,
#  'Prodipodomys gidleyi': 1.8,
#  'Prodipodomys griggsorum': 4.9,
#  'Prodipodomys idahoensis': 1.8,
#  'Prodipodomys kansensis': 10.3,
#  'Prodipodomys minor': 4.9,
#  'Prodipodomys n. sp. idahoensis': 4.9,
#  'Prodipodomys n. sp. riversidensis': 4.9,
#  'Prodipodomys n. sp. timoteoensis': 4.9,
#  'Prodipodomys riversidensis': 4.9,
#  'Prodipodomys tiheni': 4.9,
#  'Prodipodomys timoteoensis': 4.9,
#  'Proharrymys n. sp. wahlerti': 30.8,
#  'Proharrymys wahlerti': 33.3,
#  'Proheteromys aff. floridanus': 24.8,
#  'Proheteromys cf. floridanus': 30.8,
#  'Proheteromys cf. formicarum': 15.97,
#  'Proheteromys fedti': 30.8,
#  'Proheteromys floridanus': 20.43,
#  'Proheteromys formicarum': 15.97,
#  'Proheteromys gremmelsi': 30.8,
#  'Proheteromys ironcloudi': 30.8,
#  'Proheteromys maximus': 23.03,
#  'Proheteromys n. sp. cejanus': 24.8,
#  'Proheteromys n. sp. fedti': 30.8,
#  'Proheteromys n. sp. floridanus': 20.43,
#  'Proheteromys n. sp. gremmelsi': 30.8,
#  'Proheteromys n. sp. ironcloudi': 26.3,
#  'Proheteromys n. sp. matthewi': 24.8,
#  'Proheteromys n. sp. sabinensis': 23.03,
#  'Proheteromys n. sp. toledoensis': 23.03,
#  'Proheteromys sulculus': 23.03,
#  'Schizodontomys amnicolus': 20.43,
#  'Schizodontomys cf. harkseni': 24.8,
#  'Schizodontomys greeni': 30.8,
#  'Schizodontomys harkseni': 20.43,
#  'Schizodontomys n. sp. amnicolus': 20.43,
#  'Schizodontomys sulcidens': 24.8,
#  'Stratimus n. sp. strobeli': 20.43,
#  'Stratimus strobeli': 20.43,
#  'Trogomys cf. rupinimenthae': 20.43,
#  'Trogomys n. sp. rupinimenthae': 30.8,
#  'cf. Cupidinimus nebraskensis': 23.03,
#  'cf. Lignimus montis': 15.97,
#  'n. gen. Metaliomys n. sp. sevierensis': 10.3}

# %%
#creating a dictionary of last occurances
def LastOccurance(filename):
    lastocc_dict = {} #creating an empty dictionary 
    rspecies_data = open(filename, "r", encoding = "ISO-8859-15") #will open file
    lastocc_records = rspecies_data.readlines()[19:] #reads the file
    for line in lastocc_records:
        line = line.replace('\"', '') 
        lastocc_elements = line.split(",")
        species = lastocc_elements[5] #populating the species with the data in column 6
        end_year = float(lastocc_elements[15]) #populating the end year with data from column 16 while also converting to float
        lastocc_dict[species] = end_year #assigning species as keys and end year as values
    return lastocc_dict

# %%
lo_dict = LastOccurance("rat_data.csv")
lo_dict
# Out:
# {'Balantiomys borealis': 13.6,
#  'Balantiomys cf. oregonensis': 13.6,
#  'Balantiomys oregonensis': 13.6,
#  'Chaetodipus cf. formosus': 0.0117,
#  'Chaetodipus cf. hispidus': 0.3,
#  'Chaetodipus hispidus': 0.0117,
#  'Cupidinimus avawatzensis': 10.3,
#  'Cupidinimus bidahochiensis': 4.9,
#  'Cupidinimus boronensis': 13.6,
#  'Cupidinimus cf. bidahochiensis': 1.8,
#  'Cupidinimus cf. eurekensis': 13.6,
#  'Cupidinimus cf. halli': 5.333,
#  'Cupidinimus cf. kleinfelderi': 13.6,
#  'Cupidinimus cf. lindsayi': 15.97,
#  'Cupidinimus cf. tertius': 10.3,
#  'Cupidinimus cuyamensis': 10.3,
#  'Cupidinimus eurekensis': 13.6,
#  'Cupidinimus halli': 13.6,
#  'Cupidinimus kleinfelderi': 13.6,
#  'Cupidinimus lindsayi': 13.6,
#  'Cupidinimus madisonensis': 13.6,
#  'Cupidinimus n. sp. boronensis': 15.97,
#  'Cupidinimus n. sp. lindsayi': 13.6,
#  'Cupidinimus n. sp. prattensis': 10.3,
#  'Cupidinimus n. sp. smaragdinus': 13.6,
#  'Cupidinimus nebraskensis': 13.6,
#  'Cupidinimus prattensis': 10.3,
#  'Cupidinimus quartus': 10.3,
#  'Cupidinimus saskatchewanensis': 13.6,
#  'Cupidinimus tertius': 10.3,
#  'Cupidinimus whitlocki': 13.6,
#  'Dikkomys matthewi': 15.97,
#  'Dikkomys n. sp. matthewi': 20.43,
#  'Dipodomys cf. agilis': 0.0117,
#  'Dipodomys cf. deserti': 0.3,
#  'Dipodomys cf. merriami': 0.0,
#  'Dipodomys cf. ordii': 0.0117,
#  'Dipodomys cf. spectabilis': 0.0117,
#  'Dipodomys compactus': 0.3,
#  'Dipodomys hibbardi': 1.8,
#  'Dipodomys merriami': 0.0117,
#  'Dipodomys microps': 0.0,
#  'Dipodomys n. sp. hibbardi': 1.8,
#  'Dipodomys n. sp. pattersoni': 0.3,
#  'Dipodomys ordii': 0.0117,
#  'Dipodomys spectabilis': 0.0,
#  'Diprionomys cf. minimus': 4.9,
#  'Diprionomys cf. parvus': 13.6,
#  'Diprionomys n. sp. minimus': 4.9,
#  'Diprionomys n. sp. parvus': 4.9,
#  'Diprionomys parvus': 4.9,
#  'Harrymys cf. magnus': 15.97,
#  'Harrymys irvini': 15.97,
#  'Harrymys magnus': 15.97,
#  'Harrymys n. sp. canadensis': 13.6,
#  'Harrymys woodi': 15.97,
#  'Heliscomys subtilis': 13.6,
#  'Kirkomys schlaikjeri': 26.3,
#  'Lignimus cf. montis': 13.6,
#  'Lignimus montis': 13.6,
#  'Lignimus n. sp. austridakotensis': 13.6,
#  'Liomys irroratus': 0.0117,
#  'Mioheteromys agrarius': 13.6,
#  'Mioheteromys amplissimus': 13.6,
#  'Mioheteromys arcarius': 13.6,
#  'Mioheteromys cf. agrarius': 10.3,
#  'Mioheteromys cf. amplissimus': 10.3,
#  'Mioheteromys n. sp. agrarius': 10.3,
#  'Mioheteromys n. sp. amplissimus': 13.6,
#  'Mioheteromys n. sp. subterior': 13.6,
#  'Mookomys altifluminis': 13.6,
#  'Mookomys n. sp. thrinax': 13.6,
#  'Oregonomys cf. pebblespringsensis': 4.9,
#  'Oregonomys cf. sargenti': 1.8,
#  'Oregonomys magnus': 1.8,
#  'Oregonomys n. sp. pebblespringsensis': 4.9,
#  'Oregonomys pebblespringsensis': 4.9,
#  'Oregonomys sargenti': 4.9,
#  'Peridiomys n. sp. halis': 13.6,
#  'Peridiomys n. sp. rusticus': 15.97,
#  'Peridiomys rusticus': 15.97,
#  'Perodipus montanus': 0.0117,
#  'Perognathoides n. sp. madisonensis': 13.6,
#  'Perognathus brevidens': 13.6,
#  'Perognathus cf. brevidens': 13.6,
#  'Perognathus cf. flavus': 0.0117,
#  'Perognathus cf. formosus': 0.0,
#  'Perognathus cf. furlongi': 13.6,
#  'Perognathus cf. gidleyi': 0.3,
#  'Perognathus cf. mclaughlini': 4.9,
#  'Perognathus cf. minutus': 5.333,
#  'Perognathus cf. pearlettensis': 0.3,
#  'Perognathus cf. rexroadensis': 1.8,
#  'Perognathus cf. trojectioansrum': 10.3,
#  'Perognathus flavus': 0.0117,
#  'Perognathus furlongi': 5.333,
#  'Perognathus gidleyi': 1.8,
#  'Perognathus henryredfieldi': 4.9,
#  'Perognathus hispidus': 0.0117,
#  'Perognathus huastecensis': 0.0117,
#  'Perognathus intermedius': 0.0,
#  'Perognathus maldei': 1.8,
#  'Perognathus mclaughlini': 4.9,
#  'Perognathus minutus': 13.6,
#  'Perognathus n. sp. ancenensis': 13.6,
#  'Perognathus n. sp. carpenteri': 1.8,
#  'Perognathus n. sp. dunklei': 4.9,
#  'Perognathus n. sp. maldei': 1.8,
#  'Perognathus n. sp. mclaughlini': 1.8,
#  'Perognathus n. sp. pearlettensis': 1.8,
#  'Perognathus n. sp. rexroadensis': 1.8,
#  'Perognathus n. sp. stevei': 4.9,
#  'Perognathus n. sp. strigipredus': 1.8,
#  'Perognathus pearlettensis': 0.3,
#  'Perognathus stevei': 4.9,
#  'Perognathus trojectioansrum': 13.6,
#  'Pliosaccomys cf. magnus': 4.9,
#  'Pliosaccomys magnus': 4.9,
#  'Prodipodomys ? minor': 1.8,
#  'Prodipodomys centralis': 1.8,
#  'Prodipodomys cf. coquorum': 1.8,
#  'Prodipodomys cf. idahoensis': 0.3,
#  'Prodipodomys coquorum': 4.9,
#  'Prodipodomys gidleyi': 0.3,
#  'Prodipodomys griggsorum': 1.8,
#  'Prodipodomys idahoensis': 0.3,
#  'Prodipodomys kansensis': 4.9,
#  'Prodipodomys minor': 1.8,
#  'Prodipodomys n. sp. idahoensis': 1.8,
#  'Prodipodomys n. sp. riversidensis': 1.8,
#  'Prodipodomys n. sp. timoteoensis': 1.8,
#  'Prodipodomys riversidensis': 1.8,
#  'Prodipodomys tiheni': 1.8,
#  'Prodipodomys timoteoensis': 1.8,
#  'Proharrymys n. sp. wahlerti': 26.3,
#  'Proharrymys wahlerti': 30.8,
#  'Proheteromys aff. floridanus': 20.43,
#  'Proheteromys cf. floridanus': 20.43,
#  'Proheteromys cf. formicarum': 13.6,
#  'Proheteromys fedti': 26.3,
#  'Proheteromys floridanus': 15.97,
#  'Proheteromys formicarum': 13.6,
#  'Proheteromys gremmelsi': 26.3,
#  'Proheteromys ironcloudi': 26.3,
#  'Proheteromys maximus': 5.333,
#  'Proheteromys n. sp. cejanus': 20.43,
#  'Proheteromys n. sp. fedti': 26.3,
#  'Proheteromys n. sp. floridanus': 15.97,
#  'Proheteromys n. sp. gremmelsi': 26.3,
#  'Proheteromys n. sp. ironcloudi': 24.8,
#  'Proheteromys n. sp. matthewi': 20.43,
#  'Proheteromys n. sp. sabinensis': 20.44,
#  'Proheteromys n. sp. toledoensis': 20.44,
#  'Proheteromys sulculus': 5.333,
#  'Schizodontomys amnicolus': 15.97,
#  'Schizodontomys cf. harkseni': 20.43,
#  'Schizodontomys greeni': 20.43,
#  'Schizodontomys harkseni': 15.97,
#  'Schizodontomys n. sp. amnicolus': 15.97,
#  'Schizodontomys sulcidens': 20.43,
#  'Stratimus n. sp. strobeli': 15.97,
#  'Stratimus strobeli': 15.97,
#  'Trogomys cf. rupinimenthae': 15.97,
#  'Trogomys n. sp. rupinimenthae': 20.43,
#  'cf. Cupidinimus nebraskensis': 5.333,
#  'cf. Lignimus montis': 13.6,
#  'n. gen. Metaliomys n. sp. sevierensis': 4.9}

# %%
#creating a combined dictionary in which each key (species) has both first and last occurances as values

from collections import defaultdict

combined_dict = defaultdict(list) #creating lists for values within dictionary

for d in (fo_dict, lo_dict):
    for key, value in d.items():
        combined_dict[key].append(value) #append both values as a list for each key in a new combined dictionary
combined_dict
# Out:
# defaultdict(list,
#             {'Balantiomys borealis': [15.97, 13.6],
#              'Balantiomys cf. oregonensis': [15.97, 13.6],
#              'Balantiomys oregonensis': [15.97, 13.6],
#              'Chaetodipus cf. formosus': [0.126, 0.0117],
#              'Chaetodipus cf. hispidus': [1.8, 0.3],
#              'Chaetodipus hispidus': [0.126, 0.0117],
#              'Cupidinimus avawatzensis': [13.6, 10.3],
#              'Cupidinimus bidahochiensis': [10.3, 4.9],
#              'Cupidinimus boronensis': [15.97, 13.6],
#              'Cupidinimus cf. bidahochiensis': [4.9, 1.8],
#              'Cupidinimus cf. eurekensis': [15.97, 13.6],
#              'Cupidinimus cf. halli': [23.03, 5.333],
#              'Cupidinimus cf. kleinfelderi': [15.97, 13.6],
#              'Cupidinimus cf. lindsayi': [20.43, 15.97],
#              'Cupidinimus cf. tertius': [13.6, 10.3],
#              'Cupidinimus cuyamensis': [13.6, 10.3],
#              'Cupidinimus eurekensis': [15.97, 13.6],
#              'Cupidinimus halli': [15.97, 13.6],
#              'Cupidinimus kleinfelderi': [15.97, 13.6],
#              'Cupidinimus lindsayi': [15.97, 13.6],
#              'Cupidinimus madisonensis': [15.97, 13.6],
#              'Cupidinimus n. sp. boronensis': [20.43, 15.97],
#              'Cupidinimus n. sp. lindsayi': [15.97, 13.6],
#              'Cupidinimus n. sp. prattensis': [13.6, 10.3],
#              'Cupidinimus n. sp. smaragdinus': [15.97, 13.6],
#              'Cupidinimus nebraskensis': [15.97, 13.6],
#              'Cupidinimus prattensis': [13.6, 10.3],
#              'Cupidinimus quartus': [13.6, 10.3],
#              'Cupidinimus saskatchewanensis': [15.97, 13.6],
#              'Cupidinimus tertius': [13.6, 10.3],
#              'Cupidinimus whitlocki': [15.97, 13.6],
#              'Dikkomys matthewi': [20.43, 15.97],
#              'Dikkomys n. sp. matthewi': [24.8, 20.43],
#              'Dipodomys cf. agilis': [0.126, 0.0117],
#              'Dipodomys cf. deserti': [1.8, 0.3],
#              'Dipodomys cf. merriami': [0.0117, 0.0],
#              'Dipodomys cf. ordii': [0.126, 0.0117],
#              'Dipodomys cf. spectabilis': [0.126, 0.0117],
#              'Dipodomys compactus': [1.8, 0.3],
#              'Dipodomys hibbardi': [4.9, 1.8],
#              'Dipodomys merriami': [0.126, 0.0117],
#              'Dipodomys microps': [0.126, 0.0],
#              'Dipodomys n. sp. hibbardi': [4.9, 1.8],
#              'Dipodomys n. sp. pattersoni': [1.8, 0.3],
#              'Dipodomys ordii': [0.126, 0.0117],
#              'Dipodomys spectabilis': [0.126, 0.0],
#              'Diprionomys cf. minimus': [10.3, 4.9],
#              'Diprionomys cf. parvus': [15.97, 13.6],
#              'Diprionomys n. sp. minimus': [10.3, 4.9],
#              'Diprionomys n. sp. parvus': [10.3, 4.9],
#              'Diprionomys parvus': [10.3, 4.9],
#              'Harrymys cf. magnus': [20.43, 15.97],
#              'Harrymys irvini': [20.43, 15.97],
#              'Harrymys magnus': [20.43, 15.97],
#              'Harrymys n. sp. canadensis': [15.97, 13.6],
#              'Harrymys woodi': [20.43, 15.97],
#              'Heliscomys subtilis': [15.97, 13.6],
#              'Kirkomys schlaikjeri': [30.8, 26.3],
#              'Lignimus cf. montis': [15.97, 13.6],
#              'Lignimus montis': [15.97, 13.6],
#              'Lignimus n. sp. austridakotensis': [15.97, 13.6],
#              'Liomys irroratus': [0.126, 0.0117],
#              'Mioheteromys agrarius': [15.97, 13.6],
#              'Mioheteromys amplissimus': [15.97, 13.6],
#              'Mioheteromys arcarius': [15.97, 13.6],
#              'Mioheteromys cf. agrarius': [13.6, 10.3],
#              'Mioheteromys cf. amplissimus': [13.6, 10.3],
#              'Mioheteromys n. sp. agrarius': [13.6, 10.3],
#              'Mioheteromys n. sp. amplissimus': [15.97, 13.6],
#              'Mioheteromys n. sp. subterior': [15.97, 13.6],
#              'Mookomys altifluminis': [15.97, 13.6],
#              'Mookomys n. sp. thrinax': [15.97, 13.6],
#              'Oregonomys cf. pebblespringsensis': [10.3, 4.9],
#              'Oregonomys cf. sargenti': [4.9, 1.8],
#              'Oregonomys magnus': [4.9, 1.8],
#              'Oregonomys n. sp. pebblespringsensis': [10.3, 4.9],
#              'Oregonomys pebblespringsensis': [10.3, 4.9],
#              'Oregonomys sargenti': [10.3, 4.9],
#              'Peridiomys n. sp. halis': [15.97, 13.6],
#              'Peridiomys n. sp. rusticus': [20.43, 15.97],
#              'Peridiomys rusticus': [20.43, 15.97],
#              'Perodipus montanus': [0.126, 0.0117],
#              'Perognathoides n. sp. madisonensis': [15.97, 13.6],
#              'Perognathus brevidens': [15.97, 13.6],
#              'Perognathus cf. brevidens': [15.97, 13.6],
#              'Perognathus cf. flavus': [0.126, 0.0117],
#              'Perognathus cf. formosus': [0.126, 0.0],
#              'Perognathus cf. furlongi': [15.97, 13.6],
#              'Perognathus cf. gidleyi': [1.8, 0.3],
#              'Perognathus cf. mclaughlini': [10.3, 4.9],
#              'Perognathus cf. minutus': [23.03, 5.333],
#              'Perognathus cf. pearlettensis': [1.8, 0.3],
#              'Perognathus cf. rexroadensis': [4.9, 1.8],
#              'Perognathus cf. trojectioansrum': [13.6, 10.3],
#              'Perognathus flavus': [0.126, 0.0117],
#              'Perognathus furlongi': [23.03, 5.333],
#              'Perognathus gidleyi': [4.9, 1.8],
#              'Perognathus henryredfieldi': [10.3, 4.9],
#              'Perognathus hispidus': [0.126, 0.0117],
#              'Perognathus huastecensis': [0.126, 0.0117],
#              'Perognathus intermedius': [2.588, 0.0],
#              'Perognathus maldei': [4.9, 1.8],
#              'Perognathus mclaughlini': [10.3, 4.9],
#              'Perognathus minutus': [15.97, 13.6],
#              'Perognathus n. sp. ancenensis': [15.97, 13.6],
#              'Perognathus n. sp. carpenteri': [4.9, 1.8],
#              'Perognathus n. sp. dunklei': [10.3, 4.9],
#              'Perognathus n. sp. maldei': [4.9, 1.8],
#              'Perognathus n. sp. mclaughlini': [4.9, 1.8],
#              'Perognathus n. sp. pearlettensis': [4.9, 1.8],
#              'Perognathus n. sp. rexroadensis': [4.9, 1.8],
#              'Perognathus n. sp. stevei': [10.3, 4.9],
#              'Perognathus n. sp. strigipredus': [4.9, 1.8],
#              'Perognathus pearlettensis': [1.8, 0.3],
#              'Perognathus stevei': [10.3, 4.9],
#              'Perognathus trojectioansrum': [15.97, 13.6],
#              'Pliosaccomys cf. magnus': [10.3, 4.9],
#              'Pliosaccomys magnus': [10.3, 4.9],
#              'Prodipodomys ? minor': [4.9, 1.8],
#              'Prodipodomys centralis': [4.9, 1.8],
#              'Prodipodomys cf. coquorum': [4.9, 1.8],
#              'Prodipodomys cf. idahoensis': [1.8, 0.3],
#              'Prodipodomys coquorum': [10.3, 4.9],
#              'Prodipodomys gidleyi': [1.8, 0.3],
#              'Prodipodomys griggsorum': [4.9, 1.8],
#              'Prodipodomys idahoensis': [1.8, 0.3],
#              'Prodipodomys kansensis': [10.3, 4.9],
#              'Prodipodomys minor': [4.9, 1.8],
#              'Prodipodomys n. sp. idahoensis': [4.9, 1.8],
#              'Prodipodomys n. sp. riversidensis': [4.9, 1.8],
#              'Prodipodomys n. sp. timoteoensis': [4.9, 1.8],
#              'Prodipodomys riversidensis': [4.9, 1.8],
#              'Prodipodomys tiheni': [4.9, 1.8],
#              'Prodipodomys timoteoensis': [4.9, 1.8],
#              'Proharrymys n. sp. wahlerti': [30.8, 26.3],
#              'Proharrymys wahlerti': [33.3, 30.8],
#              'Proheteromys aff. floridanus': [24.8, 20.43],
#              'Proheteromys cf. floridanus': [30.8, 20.43],
#              'Proheteromys cf. formicarum': [15.97, 13.6],
#              'Proheteromys fedti': [30.8, 26.3],
#              'Proheteromys floridanus': [20.43, 15.97],
#              'Proheteromys formicarum': [15.97, 13.6],
#              'Proheteromys gremmelsi': [30.8, 26.3],
#              'Proheteromys ironcloudi': [30.8, 26.3],
#              'Proheteromys maximus': [23.03, 5.333],
#              'Proheteromys n. sp. cejanus': [24.8, 20.43],
#              'Proheteromys n. sp. fedti': [30.8, 26.3],
#              'Proheteromys n. sp. floridanus': [20.43, 15.97],
#              'Proheteromys n. sp. gremmelsi': [30.8, 26.3],
#              'Proheteromys n. sp. ironcloudi': [26.3, 24.8],
#              'Proheteromys n. sp. matthewi': [24.8, 20.43],
#              'Proheteromys n. sp. sabinensis': [23.03, 20.44],
#              'Proheteromys n. sp. toledoensis': [23.03, 20.44],
#              'Proheteromys sulculus': [23.03, 5.333],
#              'Schizodontomys amnicolus': [20.43, 15.97],
#              'Schizodontomys cf. harkseni': [24.8, 20.43],
#              'Schizodontomys greeni': [30.8, 20.43],
#              'Schizodontomys harkseni': [20.43, 15.97],
#              'Schizodontomys n. sp. amnicolus': [20.43, 15.97],
#              'Schizodontomys sulcidens': [24.8, 20.43],
#              'Stratimus n. sp. strobeli': [20.43, 15.97],
#              'Stratimus strobeli': [20.43, 15.97],
#              'Trogomys cf. rupinimenthae': [20.43, 15.97],
#              'Trogomys n. sp. rupinimenthae': [30.8, 20.43],
#              'cf. Cupidinimus nebraskensis': [23.03, 5.333],
#              'cf. Lignimus montis': [15.97, 13.6],
#              'n. gen. Metaliomys n. sp. sevierensis': [10.3, 4.9]})

# %% [markdown]
# ### Creating a file to use in Rstudio

# %%
# same process as above but abriged and easier to follow, as demonstrated in class. 
# this also gives the output to a separate file. 
infile = "clean-rat.csv"
with open(infile, 'r') as ff:
    rat_recs = ff.readlines()[1:]

# %%
#use defaultdict
from collections import defaultdict

species_ranges = defaultdict(list)


# make a dictionary
for line in rat_recs:
    species = line.split(",")[5]
    minage = float(line.split('","')[14]) # uses the values from column 15 for min age
    maxage = float(line.split('","')[15]) # uses values from column 16 for max age
    meanage = (minage + maxage) / 2
    
    species_ranges[species].append(meanage) # adds in species as the keys and mean ages as values to a list

# %%
output = open("rat-ranges.csv", "w") # this creates the new csv file where the desired data will be collected

for key in species_ranges.keys():
    ages = species_ranges[key]
    minage = min(ages)
    maxage = max(ages)
    genus = key.split(" ")[0]
    species = key
    outline = "{},{},{},{}\n".format(genus, key, minage, maxage)
    # adds in the values in this specific order
    output.write(outline)

# %% [markdown]
# ### Species Occurance Graph

# %% [markdown]
# For this portion, I will be using Rstudio in to make the graph. The code is pasted below. Please see the "rat-ranges.csv" file for the file in which the graph is based on.
#
# Also see "r-final-project.html" for the code in R.
#
# See "rat-occ.pdf" for a pdf version of the graph.

# %% [markdown]
# #### Code from Rstudio for the graph
#
# Opening the file and checking that the data table is correct.
#
# ```{r}
# #this will get the data from the csv file we made from python
# library(ggplot2)
# setwd("/home/eeb177-student/Desktop/eeb-177/homework/canids")
#
# rats <- read.csv("/home/eeb177-student/Desktop/eeb-177/homework/canids/rat-ranges.csv", header =F, as.is = T)
#
# names(rats) <- c("genus", "species", "minage", "maxage")
# head(rats)
# ```
#
# Creating the actual graph.
#
# ```{r}
# rats_occ <- ggplot(rats, aes( species, ymin = maxage, ymax=minage, colour = genus))
# rats_occ <- rats_occ + geom_linerange()
# rats_occ <- rats_occ + theme(legend.position="none") # this will get rid of the legend on the graph
# rats_occ <- rats_occ + coord_flip() # this will flip the axis to maket he graph go the other direction
# rats_occ <- rats_occ +  theme(axis.text.y = element_text(size=3)) # makes the text a more readable size
# rats_occ <- rats_occ + theme(axis.ticks.y=element_blank()) # removes the tick marks that are present on the y axis
# rats_occ <- rats_occ + scale_y_continuous(limits=c(0, 35), expand = c(0, 0), breaks=c(0, 5, 10, 15, 20, 25, 30, 35, 40)) # makes the graph fit more by removing the excess white space
# rats_occ <- rats_occ + labs(title = "Heteromyidae Fossil Occurrences", x = "Species", y = "Ma ago") + theme(plot.title = element_text(hjust = 0.5, size=22, face = "bold"), axis.title =element_text(size=20))  # adding in the title and axis labels to the graph
# rats_occ
# ```
#
# Saving the graph to in a PDF format.
# ```{r}
# ggsave(filename = "rat-occ.pdf", plot = rats_occ)
# ```

# %% [markdown]
# See "rat-occ.pdf" for the species occurrence graph!

# %%
from IPython.display import IFrame
IFrame("rat-occ.pdf", width=800, height=1000)
# Out:
#         <iframe
#             width="800"
#             height="1000"
#             src="rat-occ.pdf"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %% [markdown]
# ### PyRate Data

# %% [markdown]
# Using the same tutorial as we did during lab, I ran PyRate for my species a total of 250,000 times (my computer is SUPER slow so this was a lot for it already).
#
# See "pyrate_info/pyrate_mcmc_logs/rats_occ_1_marginal_rates_RTT.pdf" for the graphs of these!

# %%
from IPython.display import IFrame
IFrame("pyrate_info/pyrate_mcmc_logs/rats_occ_1_marginal_rates_RTT.pdf", width=1000, height=2000)
# Out:
#         <iframe
#             width="1000"
#             height="2000"
#             src="pyrate_info/pyrate_mcmc_logs/rats_occ_1_marginal_rates_RTT.pdf"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %% [markdown]
# ### Github Link
#
# https://github.com/erinsolis29/Final-Project
